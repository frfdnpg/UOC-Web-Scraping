# %%
builtwith.builtwith('https://lolamarket.com/')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-76176e57aa92> in <module>()
# ----> 1 builtwith.builtwith('https://lolamarket.com/')
#
# NameError: name 'builtwith' is not defined

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
page_LM_home = requests.get('https://lolamarket.com/')

# %%
print(page_LM_home)
# Out:
# <Response [200]>

# %%
page_LM_home.status_code
# Out:
# 200

# %%
page_LM_home.content
# Out:
# '\r\n\r\n<!DOCTYPE html>\r\n<html>\r\n\t<head id="sMeta">\r\n\r\n\t\t\r\n\t\t\r\n\r\n\t\t<meta charset="utf-8" http-equiv="Content-Type">\r\n\t\t<meta name="theme-color" content="#4FD053"> <!-- Brand -->\r\n\t\t<meta name="viewport" content = "width = device-width, initial-scale = 1, user-scalable = no" />\r\n\r\n\t\t\r\n\t\t\t<link rel="stylesheet" type="text/css" href="/_res/bootstrap/css/boot.css?t=90a3685134559d70cdb6622a413a5ccccc06c60b">\r\n\t\t\r\n\t<link rel="stylesheet" type="text/css" href="/index/page.css?t=90a3685134559d70cdb6622a413a5ccccc06c60b">\r\n\r\n\r\n\t\t<!--[if lt IE 9]>\r\n\t\t\t<script type="text/javascript" src="/_res/libs/html5shiv.min.js"></script>\r\n\t\t<![endif]-->\r\n\r\n\t\t\r\n\t\t\t<!-- Typekit Font Loader -->\r\n\t\t\t\r\n\t\t\t  \r\n\t\t\t    \r\n\t\t\t      \r\n\t\t\t      \r\n\t\t\t      \r\n\t\t\t    \r\n\t\t\t    \r\n\t\t\t  \r\n\t\t\t\r\n\t\t\r\n\r\n\t\t\r\n\t<script src="/js/bootstrap.js?t=90a3685134559d70cdb6622a413a5ccccc06c60b" defer></script>\r\n\r\n\r\n\t\t\r\n\t\t\t\r\n\t\t\t\r\n\t<!-- Favicon nonsense party -->\r\n\t<link rel="apple-touch-icon" sizes="180x180" href="/_res/bootstrap/gphx/favicon/apple-touch-icon.png">\r\n\t<link rel="icon" type="image/png" sizes="32x32" href="/_res/bootstrap/gphx/favicon/favicon-32x32.png">\r\n\t<link rel="icon" type="image/png" sizes="16x16" href="/_res/bootstrap/gphx/favicon/favicon-16x16.png">\r\n\t<link rel="manifest" href="/_res/bootstrap/gphx/favicon/manifest.json">\r\n\t<link rel="mask-icon" href="/_res/bootstrap/gphx/favicon/safari-pinned-tab.svg" color="#4fd053">\r\n\t<link rel="shortcut icon" href="/_res/bootstrap/gphx/favicon/favicon.ico">\r\n\t<meta name="msapplication-config" content="/_res/bootstrap/gphx/favicon/browserconfig.xml">\r\n\t<meta name="theme-color" content="#4fd053">\r\n\r\n\t\t\r\n\r\n\t\t\r\n\t\r\n\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\t\r\n\t\r\n\r\n\t<title data-select="title">Supermercado online | Compra a domicilio en LolaMarket.com - Inicio</title>\r\n\r\n\t<!-- FB Graph -->\r\n\t<meta property="og:type" content="website" />\r\n\t<meta data-select="title" property="og:title" content="Supermercado online | Compra a domicilio en LolaMarket.com - Inicio"/>\r\n\t<meta data-select="description" property="og:description" content="Compra online en tu supermercado online favorito desde LolaMarket.com \xe2\x9e\xa4\xe2\x9e\xa4 Compra a domicilio productos frescos de confianza con env\xc3\xados en 1 hora."/>\r\n\t<meta data-select="image" property="og:image" data-default="/_res/bootstrap/img/previews/preview.jpg"\r\n\t\tcontent="/_res/bootstrap/img/previews/preview.jpg"/>\r\n\t<meta data-select="url" property="og:url" content="es_ES"/>\r\n\t<meta property="og:site_name" content="Lola Market"/>\r\n\t<meta property="og:locale" content="" />\r\n\r\n\t<!-- Twitter cards -->\r\n\t<meta name="twitter:card" content="summary_large_image">\r\n\t<meta name="twitter:site" content="@lola_market">\r\n\t<meta data-select="title" name="twitter:title" content="Supermercado online | Compra a domicilio en LolaMarket.com - Inicio">\r\n\t<meta data-select="description" name="twitter:description" content="Compra online en tu supermercado online favorito desde LolaMarket.com \xe2\x9e\xa4\xe2\x9e\xa4 Compra a domicilio productos frescos de confianza con env\xc3\xados en 1 hora.">\r\n\t<meta data-select="image" name="twitter:image:src" data-default="/_res/bootstrap/img/previews/preview.jpg"\r\n\t\tcontent="/_res/bootstrap/img/previews/preview.jpg">\r\n\r\n\t<!-- SEO TAGS [keywords, description, owner, location, etc...] -->\r\n\t<meta data-select="description" name="description" content="Compra online en tu supermercado online favorito desde LolaMarket.com \xe2\x9e\xa4\xe2\x9e\xa4 Compra a domicilio productos frescos de confianza con env\xc3\xados en 1 hora.">\r\n\t<meta data-select="keywords" name="keywords" content="comprea, lola market, compra online, fresco, supermercado, eco, ecol\xc3\xb3gico, app hacer la compra, comida sana, compra r\xc3\xa1pida, co ...

# %%
soup = BeautifulSoup(page_LM_home.content)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head id="sMeta">
#   <meta charset="utf-8" http-equiv="Content-Type"/>
#   <meta content="#4FD053" name="theme-color"/>
#   <!-- Brand -->
#   <meta content="width = device-width, initial-scale = 1, user-scalable = no" name="viewport"/>
#   <link href="/_res/bootstrap/css/boot.css?t=90a3685134559d70cdb6622a413a5ccccc06c60b" rel="stylesheet" type="text/css"/>
#   <link href="/index/page.css?t=90a3685134559d70cdb6622a413a5ccccc06c60b" rel="stylesheet" type="text/css"/>
#   <!--[if lt IE 9]>
# 			<script type="text/javascript" src="/_res/libs/html5shiv.min.js"></script>
# 		<![endif]-->
#   <!-- Typekit Font Loader -->
#   <script defer="" src="/js/bootstrap.js?t=90a3685134559d70cdb6622a413a5ccccc06c60b">
#   </script>
#   <!-- Favicon nonsense party -->
#   <link href="/_res/bootstrap/gphx/favicon/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/_res/bootstrap/gphx/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/_res/bootstrap/gphx/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/_res/bootstrap/gphx/favicon/manifest.json" rel="manifest"/>
#   <link color="#4fd053" href="/_res/bootstrap/gphx/favicon/safari-pinned-tab.svg" rel="mask-icon"/>
#   <link href="/_res/bootstrap/gphx/favicon/favicon.ico" rel="shortcut icon"/>
#   <meta content="/_res/bootstrap/gphx/favicon/browserconfig.xml" name="msapplication-config"/>
#   <meta content="#4fd053" name="theme-color"/>
#   <title data-select="title">
#    Supermercado online | Compra a domicilio en LolaMarket.com - Inicio
#   </title>
#   <!-- FB Graph -->
#   <meta content="website" property="og:type"/>
#   <meta content="Supermercado online | Compra a domicilio en LolaMarket.com - Inicio" data-select="title" property="og:title"/>
#   <meta content="Compra online en tu supermercado online favorito desde LolaMarket.com ➤➤ Compra a domicilio productos frescos de confianza con envíos en 1 hora." data-select="description" property="og:description"/>
#   <meta content="/_res/bootstrap/img/previews/preview.jpg" data-default="/_res/bootstrap/img/previews/preview.jpg" data-select="image" property="og:image"/>
#   <meta content="es_ES" data-select="url" property="og:url"/>
#   <meta content="Lola Market" property="og:site_name"/>
#   <meta content="" property="og:locale"/>
#   <!-- Twitter cards -->
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@lola_market" name="twitter:site"/>
#   <meta content="Supermercado online | Compra a domicilio en LolaMarket.com - Inicio" data-select="title" name="twitter:title"/>
#   <meta content="Compra online en tu supermercado online favorito desde LolaMarket.com ➤➤ Compra a domicilio productos frescos de confianza con envíos en 1 hora." data-select="description" name="twitter:description"/>
#   <meta content="/_res/bootstrap/img/previews/preview.jpg" data-default="/_res/bootstrap/img/previews/preview.jpg" data-select="image" name="twitter:image:src"/>
#   <!-- SEO TAGS [keywords, description, owner, location, etc...] -->
#   <meta content="Compra online en tu supermercado online favorito desde LolaMarket.com ➤➤ Compra a domicilio productos frescos de confianza con envíos en 1 hora." data-select="description" name="description"/>
#   <meta content="comprea, lola market, compra online, fresco, supermercado, eco, ecológico, app hacer la compra, comida sana, compra rápida, compra en casa, app, compra desde el movil, compra desde smartphone" data-select="keywords" name="keywords"/>
#   <meta content="Lola Market" name="author"/>
#   <meta content="es" http-equiv="content-language"/>
#   <meta content="Spanish" name="language"/>
#   <meta content="notranslate" name="google"/>
#   <!-- Twitter Applinks -->
#   <meta content="973135261" name="twitter:app:id:iphone"/>
#   <meta content="Supermercado online | Compra a domicilio en LolaMarket.com" data-select="title" name="twitter:app:name:iphone"/>
#   <meta content="comprea://open" data-default="comprea://open" data-select="applink" name="twitter:app:url:iphone"/>
#   <meta content="com.comprea.client" name="twitter:app:id:googleplay"/>
#   <meta content="Supermercado online | Compra a domicilio en LolaMarket.com" data-select="title" name="twitter:app:name:googleplay"/>
#   <meta content="comprea://open" data-default="comprea://open" data-select="applink" name="twitter:app:url:googleplay"/>
#   <!-- Applinks -->
#   <meta content="comprea://open" data-default="comprea://open" data-select="applink" property="al:ios:url"/>
#   <meta content="973135261" property="al:ios:app_store_id"/>
#   <meta content="Supermercado online | Compra a domicilio en LolaMarket.com" property="al:ios:app_name"/>
#   <meta content="comprea://open" data-default="comprea://open" data-select="applink" name="googleplay" property="al:android:url"/>
#   <meta content="Supermercado online | Compra a domicilio en LolaMarket.com" property="al:android:app_name"/>
#   <meta content="com.comprea.client" property="al:android:package"/>
#   <meta content="/" data-select="url" property="al:web:url"/>
#   <!-- Google verification -->
#   <meta content="77IRKcOB5vODjt4o8SnS1iEKuaTgIGlTJMXviesjWMY" name="google-site-verification"/>
#  </head>
#  <body class="page " data-api="https://api.comprea.com/" data-assets="https://lolamarket.com/_res" data-baseurl="/" data-env="live">
#   <nav class="c-navigation end " id="cNavigation">
#    <div class="c-navigation-inner">
#     <h2 class="c-navigation-logo" id="cNavigationLogo">
#      <a href="/?fl=true" title="Lola Market — Inicio">
#       Lola Market — Inicio
#      </a>
#     </h2>
#     <ul id="cNavigationLinks">
#      <li>
#       <a href="/?fl=true">
#        Lola Market
#       </a>
#      </li>
#      <li>
#       <a href="/features/">
#        Características
#       </a>
#      </li>
#      <li>
#       <a href="/app/">
#        App
#       </a>
#      </li>
#      <!-- <li><a href="/shopper/">Los Shoppers</a></li> -->
#      <li>
#       <a class="b-action" href="/tienda" target="_blank">
#        Empieza tu compra
#       </a>
#      </li>
#     </ul>
#    </div>
#   </nav>
#   <section class="p-wrapper">
#    <div id="Start">
#     <section class="p-intro" data-selector="hero">
#      <div class="p-block-inner">
#       <header class="p-header" id="pHeader">
#        <h1 class="p-intro-logo">
#         Lola Market - Supermercado online
#        </h1>
#        <h2>
#         Tu compra de productos frescos y supermercado en casa en 1h
#        </h2>
#        <a class="b-action brand XL" data-action="mainAction" data-track="store" href="/tienda" target="_blank">
#         Empieza tu compra
#        </a>
#        <div class="p-form--buttons p-form-message" data-select="buttonsMobile" hidden="">
#         <ul>
#          <li>
#           <a class="b-action brand b-action-download ios" data-select="buttoniOS" data-trigger="downloadApp" href="https://itunes.apple.com/es/app/comprea/id973135261?ls=1&amp;mt=8" target="_blank">
#            <span>
#             Gratis en
#            </span>
#            App Store
#           </a>
#          </li>
#          <li>
#           <a class="b-action brand b-action-download android" data-select="buttonAndroid" data-trigger="downloadApp" href="https://play.google.com/store/apps/details?id=com.comprea.client&amp;utm_source=comprea&amp;utm_campaign=comprea_sources" target="_blank">
#            <span>
#             Gratis en
#            </span>
#            Google Play
#           </a>
#          </li>
#         </ul>
#        </div>
#       </header>
#      </div>
#      <section class="p-city-markets loading">
#       <ul class="p-tabs" data-selector="marketstabs">
#        <li data-allowedtypes="mercadona,herbolarionavarro,carrefourmarket,dia,elcorteingles,mercadodelapaz,mercadochamartin,mercadochamberi,enterbio,usmarket" data-city="madrid">
#         <a href="#madrid">
#          Madrid
#         </a>
#        </li>
#        <li data-allowedtypes="mercadona,elcorteingles,caprabo,tasteofamerica,mercadosantacaterina,mercadoboqueria" data-city="barcelona">
#         <a href="#barcelona">
#          Barcelona
#         </a>
#        </li>
#        <li data-allowedtypes="mercadona,dia,mercadocentral,herbolarionavarro,elcorteingles" data-city="valencia">
#         <a href="#valencia">
#          Valencia
#         </a>
#        </li>
#        <li data-allowedtypes="mercadona,carrefourmarket,dia,elcorteingles" data-city="la-coruna">
#         <a href="#la-coruna">
#          La Coruña
#         </a>
#        </li>
#        <li data-allowedtypes="mercadona,carrefourmarket,dia,elcorteingles" data-city="bilbao">
#         <a href="#bilbao">
#          Bilbao
#         </a>
#        </li>
#        <li data-allowedtypes="mercadona,carrefourmarket,dia,elcorteingles" data-city="zaragoza">
#         <a href="#zaragoza">
#          Zaragoza
#         </a>
#        </li>
#       </ul>
#       <ul class="p-markets-selector" data-selector="markets">
#        <li data-market="mercadona">
#         <a data-action="mercadonaMain" data-track="store" href="/tienda/mercadona" target="_blank" title="Ver Mercadona en Lola Market">
#          <figure>
#           <img src="https://api.comprea.com/bundles/asset/company/ic_circled_mercadona.png"/>
#          </figure>
#          <h2>
#           Mercadona
#          </h2>
#          <p>
#           Productos de supermercado.
#          </p>
#         </a>
#        </li>
#        <li data-market="carrefourmarket">
#         <a data-action="carrefourmarketMain" data-track="store" href="/tienda/carrefour-market" target="_blank" title="Ver Carrefour Market en Lola Market">
#          <figure>
#           <img src="https://api.comprea.com/bundles/asset/company/ic_circled_carrefour.png"/>
#          </figure>
#          <h2>
#           Carrefour Market
#          </h2>
#          <p>
#           Productos de supermercado.
#          </p>
#         </a>
#        </li>
#        <li data-market="dia">
#         <a data-action="diaMain" data-track="store" href="/tienda/dia" target="_blank" title="Ver Día en Lola Market">
#          <figure>
#           <span class="p-market-badge">
#            Especial
#           </span>
#           <img src="https://api.comprea.com/bundles/asset/company/ic_circled_dia.png"/>
#          </figure>
#          <h2>
#           DÍA
#          </h2>
#          <p>
#           Mismo precio que en tienda.
#          </p>
#         </a>
#        </li>
#        <li data-market="caprabo">
#         <a data-action="capraboMain" data-track="store" href="/tienda/caprabo" target="_blank" title="Ver Caprabo en Lola Market">
#          <figure>
#           <img src="https://api.comprea.com/bundles/asset/company/ic_circled_caprabo.png"/>
#          </figure>
#          <h2>
#           Caprabo
#          </h2>
#          <p>
#           Els productes de sempre.
#          </p>
#         </a>
#        </li>
#        <li data-market="elcorteingles">
#         <a data-action="elcorteinglesMain" data-track="store" href="/tienda/el-corte-ingles" target="_blank" title="Ver El Corte Inglés en Lola Market">
#          <figure>
#           <img src="https://api.comprea.com/bundles/asset/company/ic_circled_elcorteingles.png"/>
#          </figure>
#          <h2>
#           El Corte Inglés
#          </h2>
#          <p>
#           Primeras marcas de supermercado.
#          </p>
#         </a>
#        </li>
#        <li data-market="mercadocentral">
#         <a data-action="mercadocentralMain" data-track="store" href="/tienda/mercado-central" target="_blank" title="Ver Mercado Central en Lola Market">
#          <figure>
#           <img src="/_res/bootstrap/gphx/markets/ic_circled_mercadocentral.png"/>
#          </figure>
#          <h2>
#           Mercado Central
#          </h2>
#          <p>
#           Los alimentos más frescos.
#          </p>
#         </a>
#        </li>
#        <li data-market="mercadoboqueria">
#         <a href="/tienda/mercado-boqueria" target="_blank" title="Ver Mercado de la Boquería en Lola Market">
#          <figure>
#           <span class="p-market-badge">
#            Especial
#           </span>
#           <img src="https://api.comprea.com/bundles/asset/company/ic_circled_mercado_boqueria.png"/>
#          </figure>
#          <h2>
#           Mercado de la Boquería
#          </h2>
#          <p>
#           Templo de gastronomía.
#          </p>
#         </a>
#        </li>
#        <li data-market="mercadosantacaterina">
#         <a href="/tienda/mercado-santa-caterina" target="_blank" title="Ver Mercado de Santa Caterina en Lola Market">
#          <figure>
#           <span class="p-market-badge">
#            Especial
#           </span>
#           <img src="https://api.comprea.com/bundles/asset/company/ic_circled_mercado_santa_caterina.png"/>
#          </figure>
#          <h2>
#           Mercado de Santa Caterina
#          </h2>
#          <p>
#           Producto freso de la mayor calidad.
#          </p>
#         </a>
#        </li>
#        <li data-market="mercadodelapaz">
#         <a href="/tienda/mercado-paz" target="_blank" title="Ver Mercado de la Paz en Lola Market">
#          <figure>
#           <span class="p-market-badge">
#            Especial
#           </span>
#           <img src="https://api.comprea.com/bundles/asset/company/ic_circled_mercado_de_la_paz.png"/>
#          </figure>
#          <h2>
#           Mercado de la Paz
#          </h2>
#          <p>
#           Alimentos frescos de mercado.
#          </p>
#         </a>
#        </li>
#        <li data-market="mercadochamartin">
#         <a href="/tienda/mercado-chamartin" target="_blank" title="Ver Mercado de Chamartín en Lola Market">
#          <figure>
#           <span class="p-market-badge">
#            Especial
#           </span>
#           <img src="https://api.comprea.com/bundles/asset/company/ic_circled_mercado_chamartin.png"/>
#          </figure>
#          <h2>
#           Mercado de Chamartín
#          </h2>
#          <p>
#           Alimentos frescos de mercado.
#          </p>
#         </a>
#        </li>
#        <li data-market="mercadochamberi">
#         <a href="/tienda/mercado-chamberi" target="_blank" title="Ver Mercado de Chamberí en Lola Market">
#          <figure>
#           <span class="p-market-badge">
#            Especial
#           </span>
#           <img src="https://api.comprea.com/bundles/asset/company/ic_circled_mercado_de_chamberi.png"/>
#          </figure>
#          <h2>
#           Mercado de Chamberí
#          </h2>
#          <p>
#           Amplia gama de productos frescos.
#          </p>
#         </a>
#        </li>
#        <li data-market="herbolarionavarro">
#         <a data-action="herbolarionavarroMain" data-track="store" href="/tienda/ecologicos-h-navarro" target="_blank" title="Ver Ecológicos H. Navarro en Lola Market">
#          <figure>
#           <img src="https://api.comprea.com/bundles/asset/company/ic_circled_herbolarios_navarro.png"/>
#          </figure>
#          <h2>
#           Ecológicos H. Navarro
#          </h2>
#          <p>
#           Productos de Herbolarios Navarro.
#          </p>
#         </a>
#        </li>
#        <li data-market="enterbio">
#         <a href="/tienda/enter-bio" target="_blank" title="Ver EnterBio en Lola Market">
#          <figure>
#           <span class="p-market-badge">
#            Especial
#           </span>
#           <img src="https://api.comprea.com/bundles/asset/company/ic_circled_enter_bio.png"/>
#          </figure>
#          <h2>
#           EnterBio
#          </h2>
#          <p>
#           Productos ecológicos de 1ª calidad.
#          </p>
#         </a>
#        </li>
#        <li data-market="usmarket">
#         <a href="/tienda/us-market" target="_blank" title="Ver US Market en Lola Market">
#          <figure>
#           <span class="p-market-badge">
#            Especial
#           </span>
#           <img src="https://api.comprea.com/bundles/asset/company/ic_circled_us_market.png"/>
#          </figure>
#          <h2>
#           US Market
#          </h2>
#          <p>
#           American food &amp; things.
#          </p>
#         </a>
#        </li>
#        <li data-market="tasteofamerica">
#         <a href="/tienda/taste-of-america" target="_blank" title="Ver Taste of America en Lola Market">
#          <figure>
#           <span class="p-market-badge">
#            Especial
#           </span>
#           <img src="https://api.comprea.com/bundles/asset/company/ic_circled_taste_of_america.png"/>
#          </figure>
#          <h2>
#           Taste of America
#          </h2>
#          <p>
#           Tienda de productos americanos.
#          </p>
#         </a>
#        </li>
#       </ul>
#      </section>
#     </section>
#    </div>
#    <section class="p-features" id="pFeatures">
#     <div class="p-block-inner">
#      <section>
#       <span class="p-feature-icon" data-icon="/index/gphx/ic_delivery_1h.svg" data-size="XL">
#       </span>
#       <h2>
#        Envío por 4,90€
#       </h2>
#       <p>
#        Elige la hora de entrega por 4,90€ o tenlo en casa en 1h por 6,90€. No vuelvas a esperar toda la tarde a que llegue la compra.
#       </p>
#      </section>
#      <section>
#       <span class="p-feature-icon" data-icon="/index/gphx/ic_profile.svg" data-size="XL">
#       </span>
#       <h2>
#        Servicio personalizado
#       </h2>
#       <p>
#        Un Shopper hará tu compra como si fuera la suya, buscando siempre lo mejor para ti. Tendrás contacto directo con el Shopper.
#       </p>
#      </section>
#      <section>
#       <span class="p-feature-icon" data-icon="/index/gphx/ic_mart.svg" data-size="XL">
#       </span>
#       <h2>
#        Productos de confianza
#       </h2>
#       <p>
#        Elige entre uno de nuestros supermercados online para hacer tu compra, por ejemplo Mercadona o Carrefour.
#       </p>
#      </section>
#     </div>
#    </section>
#    <section class="p-block p-block--devices" id="How">
#     <div class="p-block-inner">
#      <header class="p-block-start p-claims">
#       <h2>
#        ¿Cómo funciona?
#       </h2>
#       <p>
#        Añade productos a tu carrito desde la app o la web de Lola Market, elige una hora de entrega y un Shopper profesional se encargará del resto.
#       </p>
#       <figure>
#        <img data-src="/index/gphx/flow.svg"/>
#       </figure>
#      </header>
#      <section class="p-devices start">
#       <figure>
#        <img data-src="/index/img/devices.png"/>
#       </figure>
#      </section>
#      <section class="p-devices end">
#       <figure>
#        <img data-src="/index/img/devices.png"/>
#       </figure>
#      </section>
#      <section class="p-checker p-block-start" data-select="checker">
#       <form class="p-form p-form--zip shown" data-trigger="checkZIP">
#        <fieldset>
#         <p class="p-form-message">
#          Escribe tu código postal y empieza a comprar
#         </p>
#         <div class="p-form-field">
#          <label class="p-field">
#           <input data-read="zipCode" maxlength="5" placeholder="Tu código postal" type="number"/>
#          </label>
#          <button class="p-action" data-icon="/index/gphx/ic_location.svg" data-size="M" data-trigger="getUserZip" type="button">
#           Usar el código postal de mi ubicación actual
#          </button>
#          <span class="b-spinner brand" data-select="zipLoading">
#           Cargando...
#          </span>
#          <div class="p-wrapper-action">
#           <p class="p-field-error" data-select="zipError" hidden="">
#            El código postal es incorrecto
#           </p>
#          </div>
#         </div>
#        </fieldset>
#       </form>
#       <form class="p-form p-form--email animate-from-bottom" data-trigger="submitEmail" hidden="">
#        <fieldset>
#         <p class="p-form-message p-form-message-result" data-select="legendInfo" hidden="">
#          <span data-select="legendmessage">
#          </span>
#          Indícanos tu e-mail y te avisaremos cuando esté disponible en tu ciudad.
#         </p>
#         <p class="p-form-message p-form-message-result legal" data-select="legendLegal" hidden="">
#          Indicándonos tu e-mail aceptas nuestra
#          <a href="/legal/#privacy" target="_blank">
#           política de privacidad
#          </a>
#          y
#          <a href="/legal/#terms" target="_blank">
#           términos del servicio
#          </a>
#          .
#         </p>
#         <div class="p-form-field">
#          <label class="p-field">
#           <input data-read="email" placeholder="Introduce tu e-mail" type="email"/>
#          </label>
#          <div class="p-wrapper-action">
#           <button class="p-submit" data-trigger="actionSubmit" hidden="" type="button">
#            Enviar
#            <span class="b-spinner brand">
#             Cargando...
#            </span>
#           </button>
#          </div>
#         </div>
#        </fieldset>
#       </form>
#       <div class="p-form--buttons p-form-message animate-from-bottom" data-select="buttonsSuccess" hidden="">
#        Perfecto, repartimos en
#        <span data-write="postalCode">
#        </span>
#        .
# 		Descarga la app y haz tu primera compra.
#        <ul>
#         <li>
#          <a class="b-action XL light b-action-download ios" data-trigger="downloadApp" href="https://itunes.apple.com/es/app/comprea/id973135261?ls=1&amp;mt=8" target="_blank">
#           <span>
#            Gratis en
#           </span>
#           App Store
#          </a>
#         </li>
#         <li>
#          <a class="b-action XL light b-action-download android" data-trigger="downloadApp" href="https://play.google.com/store/apps/details?id=com.comprea.client&amp;utm_source=comprea&amp;utm_campaign=comprea_sources" target="_blank">
#           <span>
#            Gratis en
#           </span>
#           Google Play
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="p-form--store p-form-message animate-from-bottom" data-select="storeSuccess" hidden="">
#        Perfecto, repartimos en
#        <span data-write="postalCode">
#        </span>
#        .
# 		Te estamos llevando a la tienda...
#       </div>
#       <div class="p-form--buttons p-form-message" data-select="buttonsMobile" hidden="">
#        Descarga la app y haz tu primera compra.
#        <ul>
#         <li>
#          <a class="b-action XL light b-action-download ios" data-select="buttoniOS" data-trigger="downloadApp" href="https://itunes.apple.com/es/app/comprea/id973135261?ls=1&amp;mt=8" target="_blank">
#           <span>
#            Gratis en
#           </span>
#           App Store
#          </a>
#         </li>
#         <li>
#          <a class="b-action XL light b-action-download android" data-select="buttonAndroid" data-trigger="downloadApp" href="https://play.google.com/store/apps/details?id=com.comprea.client&amp;utm_source=comprea&amp;utm_campaign=comprea_sources" target="_blank">
#           <span>
#            Gratis en
#           </span>
#           Google Play
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="p-form--success p-form-message animate-from-bottom" data-select="legendSuccess" hidden="">
#        Genial, te avisaremos a
#        <span data-write="emailAccount">
#        </span>
#        Mientras tanto síguenos en las redes sociales.
#        <ul class="p-form-social b-social-icons">
#         <li class="twitter">
#          <a href="https://twitter.com/lola_market" target="_blank" title="Lola Market en Twitter">
#           Twitter
#          </a>
#         </li>
#         <li class="facebook">
#          <a href="https://www.facebook.com/LolaMarketApp" target="_blank" title="Lola Market en Facebook">
#           Facebook
#          </a>
#         </li>
#         <li class="instagram">
#          <a href="https://www.instagram.com/lolamarket/" target="_blank" title="Lola Market en Instagram">
#           Instagram
#          </a>
#         </li>
#        </ul>
#       </div>
#      </section>
#     </div>
#    </section>
#    <div id="Shoppers">
#     <section class="p-block p-block--shopper" data-bg="/index/img/shopper.jpg">
#      <div class="p-block-inner">
#       <header class="p-block-end p-claims">
#        <h2>
#         ¿Qué es un Shopper?
#        </h2>
#        <p>
#         Son personas de tu ciudad formadas por Lola Market que harán tu compra como si fuera la suya, siempre buscando los mejores productos para ti.
#        </p>
#       </header>
#       <section class="p-checker p-block-end" data-select="checker">
#        <form class="p-form p-form--zip shown" data-trigger="checkZIP">
#         <fieldset>
#          <p class="p-form-message">
#           Escribe tu código postal y empieza a comprar
#          </p>
#          <div class="p-form-field">
#           <label class="p-field">
#            <input data-read="zipCode" maxlength="5" placeholder="Tu código postal" type="number"/>
#           </label>
#           <button class="p-action" data-icon="/index/gphx/ic_location.svg" data-size="M" data-trigger="getUserZip" type="button">
#            Usar el código postal de mi ubicación actual
#           </button>
#           <span class="b-spinner brand" data-select="zipLoading">
#            Cargando...
#           </span>
#           <div class="p-wrapper-action">
#            <p class="p-field-error" data-select="zipError" hidden="">
#             El código postal es incorrecto
#            </p>
#           </div>
#          </div>
#         </fieldset>
#        </form>
#        <form class="p-form p-form--email animate-from-bottom" data-trigger="submitEmail" hidden="">
#         <fieldset>
#          <p class="p-form-message p-form-message-result" data-select="legendInfo" hidden="">
#           <span data-select="legendmessage">
#           </span>
#           Indícanos tu e-mail y te avisaremos cuando esté disponible en tu ciudad.
#          </p>
#          <p class="p-form-message p-form-message-result legal" data-select="legendLegal" hidden="">
#           Indicándonos tu e-mail aceptas nuestra
#           <a href="/legal/#privacy" target="_blank">
#            política de privacidad
#           </a>
#           y
#           <a href="/legal/#terms" target="_blank">
#            términos del servicio
#           </a>
#           .
#          </p>
#          <div class="p-form-field">
#           <label class="p-field">
#            <input data-read="email" placeholder="Introduce tu e-mail" type="email"/>
#           </label>
#           <div class="p-wrapper-action">
#            <button class="p-submit" data-trigger="actionSubmit" hidden="" type="button">
#             Enviar
#             <span class="b-spinner light">
#              Cargando...
#             </span>
#            </button>
#           </div>
#          </div>
#         </fieldset>
#        </form>
#        <div class="p-form--buttons p-form-message animate-from-bottom" data-select="buttonsSuccess" hidden="">
#         Perfecto, repartimos en
#         <span data-write="postalCode">
#         </span>
#         .
# 		Descarga la app y haz tu primera compra.
#         <ul>
#          <li>
#           <a class="b-action XL brand b-action-download ios" data-trigger="downloadApp" href="https://itunes.apple.com/es/app/comprea/id973135261?ls=1&amp;mt=8" target="_blank">
#            <span>
#             Gratis en
#            </span>
#            App Store
#           </a>
#          </li>
#          <li>
#           <a class="b-action XL brand b-action-download android" data-trigger="downloadApp" href="https://play.google.com/store/apps/details?id=com.comprea.client&amp;utm_source=comprea&amp;utm_campaign=comprea_sources" target="_blank">
#            <span>
#             Gratis en
#            </span>
#            Google Play
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="p-form--store p-form-message animate-from-bottom" data-select="storeSuccess" hidden="">
#         Perfecto, repartimos en
#         <span data-write="postalCode">
#         </span>
#         .
# 		Te estamos llevando a la tienda...
#        </div>
#        <div class="p-form--buttons p-form-message" data-select="buttonsMobile" hidden="">
#         Descarga la app y haz tu primera compra.
#         <ul>
#          <li>
#           <a class="b-action XL brand b-action-download ios" data-select="buttoniOS" data-trigger="downloadApp" href="https://itunes.apple.com/es/app/comprea/id973135261?ls=1&amp;mt=8" target="_blank">
#            <span>
#             Gratis en
#            </span>
#            App Store
#           </a>
#          </li>
#          <li>
#           <a class="b-action XL brand b-action-download android" data-select="buttonAndroid" data-trigger="downloadApp" href="https://play.google.com/store/apps/details?id=com.comprea.client&amp;utm_source=comprea&amp;utm_campaign=comprea_sources" target="_blank">
#            <span>
#             Gratis en
#            </span>
#            Google Play
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="p-form--success p-form-message animate-from-bottom" data-select="legendSuccess" hidden="">
#         Genial, te avisaremos a
#         <span data-write="emailAccount">
#         </span>
#         Mientras tanto síguenos en las redes sociales.
#         <ul class="p-form-social b-social-icons">
#          <li class="twitter">
#           <a href="https://twitter.com/lola_market" target="_blank" title="Lola Market en Twitter">
#            Twitter
#           </a>
#          </li>
#          <li class="facebook">
#           <a href="https://www.facebook.com/LolaMarketApp" target="_blank" title="Lola Market en Facebook">
#            Facebook
#           </a>
#          </li>
#          <li class="instagram">
#           <a href="https://www.instagram.com/lolamarket/" target="_blank" title="Lola Market en Instagram">
#            Instagram
#           </a>
#          </li>
#         </ul>
#        </div>
#       </section>
#      </div>
#     </section>
#    </div>
#    <section class="p-block p-block--apply" id="More">
#     <div class="p-grid" data-select="grid">
#      <img data-src="/index/gphx/ic_category_001.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_002.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_005.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_007.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_025.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_026.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_034.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_037.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_045.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_055.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_057.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_062.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_082.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_016.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_019.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_043.svg" hidden=""/>
#      <img data-src="/index/gphx/ic_category_076.svg" hidden=""/>
#     </div>
#     <div class="p-block-inner p-claims">
#      <p id="Apply">
#       ¿Buscas un empleo con horario flexible y bien remunerado en tu ciudad?
#      </p>
#      <a class="b-action light XL" href="/shopper/">
#       Hazte Shopper
#      </a>
#     </div>
#    </section>
#    <section class="p-block p-block--press" id="Press">
#     <p>
#      Hablan de nosotros
#     </p>
#     <ul class="p-block-inner">
#      <li>
#       <a href="http://www.elreferente.es/Innovadores/comprea-empieza-a-funcionar-en-valencia-28416" target="_blank" title="El Referente: Lola Market empieza a funcionar en Valencia">
#        <img alt="El Referente" src="/index/img/press_logos/elreferente.png"/>
#       </a>
#      </li>
#      <li>
#       <a href="http://www.emprendedores.es/ideas-de-negocio/comprea" target="_blank" title="Emprendedores: Lola Market, para quitarte pesos de encima">
#        <img alt="Emprendedores" src="/index/img/press_logos/emprendedores.png"/>
#       </a>
#      </li>
#      <li>
#       <a href="https://www.youtube.com/watch?v=1SBrAOzvcSo" target="_blank" title="Lola Market en el telediario nacional de TVE a las 15:00 ">
#        <img alt="Telediario TVE" src="/index/img/press_logos/tve.png"/>
#       </a>
#      </li>
#      <li>
#       <a href="http://www.lasprovincias.es/agencias/valencia/201504/20/llega-espania-compra-productos-367700.html" target="_blank" title="Las Provincias: Llega a España la app que compra por ti los productos frescos y ecológicos">
#        <img alt="Las Provincias" src="/index/img/press_logos/lasprovincias.png"/>
#       </a>
#      </li>
#      <li>
#       <a href="http://www.valenciaplaza.com/ver/151476/comprea--como-tener-productos-frescos-en-casa-sin-ir-al-mercado.html" target="_blank" title="Valencia Plaza: Lola Market, cómo tener productos frescos en casa sin ir al mercado">
#        <img alt="Valencia Plaza" src="/index/img/press_logos/valenciaplaza.png"/>
#       </a>
#      </li>
#      <li>
#       <a href="http://www.levante-emv.com/ingenio/2015/04/20/valencia-estrena-app-compra/1253512.html" target="_blank" title="Levante: La app que va a la compra por ti">
#        <img alt="Levante" src="/index/img/press_logos/levante.png"/>
#       </a>
#      </li>
#     </ul>
#    </section>
#    <section class="p-end">
#     <h2>
#      ¿Aún no te hemos convencido?
#     </h2>
#     <p>
#      Escríbenos a
#      <a href="mailto:info@lolamarket.com">
#       info@lolamarket.com
#      </a>
#      y
#      <br/>
#      resolveremos todas tus dudas.
#     </p>
#    </section>
#    <footer class="c-footer" id="cFooter">
#     <section class="c-footer-block">
#      <h2>
#       <a href="/?fl=true">
#        Lola Market
#       </a>
#      </h2>
#      <ul>
#       <li>
#        <a href="/?fl=true">
#         Inicio
#        </a>
#       </li>
#       <li>
#        <a href="/#How?fl=true">
#         Cómo funciona
#        </a>
#       </li>
#       <!-- <li><a href="/#Shoppers?fl=true">Los Shoppers</a></li> -->
#       <li>
#        <a href="/features/">
#         Características
#        </a>
#       </li>
#       <li>
#        <a data-action="footerAction" data-track="store" href="/tienda" target="_blank">
#         Supermercado online
#        </a>
#       </li>
#       <li>
#        <a href="/donar-alimentos">
#         Donar alimentos
#        </a>
#       </li>
#      </ul>
#     </section>
#     <section class="c-footer-block" style="display: none">
#      <h2>
#       <a href="/shopper/">
#        Shoppers
#       </a>
#      </h2>
#      <ul>
#       <li>
#        <a href="/shopper/">
#         Información
#        </a>
#       </li>
#       <li>
#        <a href="https://lolamarket.typeform.com/to/MFGjoz">
#         Solicitud
#        </a>
#       </li>
#      </ul>
#     </section>
#     <section class="c-footer-block">
#      <h2>
#       <a href="/app/">
#        Aplicaciones
#       </a>
#      </h2>
#      <ul>
#       <li>
#        <a href="/app/ios">
#         Para iPhone
#        </a>
#       </li>
#       <li>
#        <a href="/app/android">
#         Para Android
#        </a>
#       </li>
#      </ul>
#     </section>
#     <section class="c-footer-block">
#      <h2>
#       <a href="https://twitter.com/lola_market" target="_blank">
#        Redes
#       </a>
#      </h2>
#      <ul>
#       <li>
#        <a href="http://lolamarket.com/blog" target="_blank">
#         Blog
#        </a>
#       </li>
#       <li>
#        <a href="https://twitter.com/lola_market" target="_blank">
#         Twitter
#        </a>
#       </li>
#       <li>
#        <a href="https://www.facebook.com/LolaMarketApp" target="_blank">
#         Facebook
#        </a>
#       </li>
#       <li>
#        <a href="https://plus.google.com/107499539353763713857" rel="publisher" target="_blank">
#         Google+
#        </a>
#       </li>
#      </ul>
#     </section>
#     <section class="c-footer-block">
#      <h2>
#       <a href="/faq/">
#        Dudas
#       </a>
#      </h2>
#      <ul>
#       <li>
#        <a href="/faq/">
#         Populares
#        </a>
#       </li>
#       <li>
#        <a href="/faq/#about">
#         Sobre Lola Market
#        </a>
#       </li>
#       <li>
#        <a href="/faq/#prices">
#         Inventario y precios
#        </a>
#       </li>
#       <li>
#        <a href="/faq/#orders">
#         Mis pedidos
#        </a>
#       </li>
#       <!-- <li><a href="/faq/#shoppers">Los Shoppers</a></li> -->
#       <li>
#        <a href="/faq/#contact">
#         Formas de contacto
#        </a>
#       </li>
#      </ul>
#     </section>
#     <section class="c-footer-block">
#      <h2>
#       <a href="/legal/">
#        Legal
#       </a>
#      </h2>
#      <ul>
#       <li>
#        <a href="/legal/#privacy" target="_blank">
#         Política de privacidad
#        </a>
#       </li>
#       <li>
#        <a href="/legal/#terms" target="_blank">
#         Condiciones generales
#        </a>
#       </li>
#       <li>
#        <a href="/legal/#service" target="_blank">
#         Términos del servicio
#        </a>
#       </li>
#       <li>
#        <a href="/legal/#cookies" target="_blank">
#         Uso de cookies
#        </a>
#       </li>
#       <li>
#        <a href="https://lolamarket.com/members/summons" target="_blank">
#         Información a socios
#        </a>
#       </li>
#      </ul>
#     </section>
#     <section class="c-footer-about">
#      <h2 class="c-footer-about-logo">
#       <a href="/">
#        <img src="/_res/modules/c_footer/logo.svg" title="Lola Market por Lola Market"/>
#       </a>
#      </h2>
#      <p>
#       Tu compra hecha a mano por un Shopper profesional. Entregada en 1 hora.
#      </p>
#      <ul class="c-footer-social b-social-icons">
#       <li class="twitter">
#        <a href="https://twitter.com/lola_market" target="_blank" title="Lola Market en Twitter">
#         Twitter
#        </a>
#       </li>
#       <li class="facebook">
#        <a href="https://www.facebook.com/LolaMarketApp" target="_blank" title="Lola Market en Facebook">
#         Facebook
#        </a>
#       </li>
#       <li class="instagram">
#        <a href="https://www.instagram.com/lolamarket/" target="_blank" title="Lola Market en Instagram">
#         Instagram
#        </a>
#       </li>
#      </ul>
#      <ul class="c-footer-powered">
#       <li class="c-footer-powered-secure">
#        <a href="https://stripe.com/es" target="_blank" title="Stripe">
#         <img src="/_res/modules/c_footer/img_secure.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="http://www.enisa.es/" target="_blank" title="ENISA">
#         <img src="/_res/modules/c_footer/enisa.png"/>
#        </a>
#       </li>
#      </ul>
#     </section>
#    </footer>
#    <section class="c-notice" hidden="" id="cNotice">
#     <a class="c-notice-close" data-icon="/_res/modules/c_notice/ic_close.svg" data-size="XS" href="#" id="cNoticeClose" title="Cerrar aviso">
#      Cerrar
#     </a>
#     <p id="cNoticeContent">
#      #content#
#     </p>
#    </section>
#   </section>
#   <section class="c-cookies" hidden="" id="cCookies">
#    <p>
#     Hacemos uso de cookies propias y de terceros tanto analíticas cómo funcionales y sociales. Navegando por nuestra página aceptas su uso.
#     <button class="b-action" id="cCookiesAction">
#      Entendido
#     </button>
#     <a href="/legal/#cookies" target="_blank">
#      Más información
#     </a>
#    </p>
#   </section>
#  </body>
# </html>

# %%
page_dia = requests.get('https://lolamarket.com/')
