# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url_analisis = 'https://www.codigospostales.com/'
peticion = requests.get(url_analisis)

# %%
soup = BeautifulSoup(peticion.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Codigos Postales de España
#   </title>
#   <link href="estilocp.css" rel="stylesheet" type="text/css"/>
#   <meta content="buscador de codigos postales de España" name="Keywords"/>
#   <meta content="Códigos postales de España. Buscar códigos por provincia. Mapas de códigos postales" name="Description"/>
#   <meta content="Luis G Manzaneque" name="Author"/>
#   <meta content="eivyt0LgrfYn93FU0vv6i/OUz2SMzb8pSI0KvBZeWeY=" name="verify-v1"/>
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-599750-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#   </script>
#   <script>
#    function CambiaDestino(){
#   document.getElementById("cod5").formAction = document.getElementById("codigo").value;
# }
#   </script>
#   <script type="application/ld+json">
#    {
#   "@context": "http://schema.org",
#   "@type": "WebSite",
#   "url": "https://www.codigospostales.com/",
#   "potentialAction": {
#     "@type": "SearchAction",
#     "target": "https://www.codigospostales.com/busca.html?q={search_term_string}",
#     "query-input": "required name=search_term_string"
#   }
# }
#   </script>
#  </head>
#  <body>
#   <h1>
#    <a href="/">
#     Códigos Postales
#    </a>
#   </h1>
#   <script>
#    (function() {
#     var cx = 'partner-pub-2125689151323495:rdpif6-sxu6';
#     var gcse = document.createElement('script');
#     gcse.type = 'text/javascript';
#     gcse.async = true;
#     gcse.src = 'https://cse.google.com/cse.js?cx=' + cx;
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(gcse, s);
#   })();
#   </script>
#   <style type="text/css">
#    input.gsc-input {
#  font-size: 20px;
# }
# input.gsc-search-button {
#  font: normal 140% Arial;
#  height: 28px;
#  color: #003366;
# }
#  .gsc-control-searchbox-only {
#     padding: 1em;
#     width: auto;
# }
# #___gcse_0 {
# 	box-shadow: 0 0 16px 2px #336;
# }
#   </style>
#   <fieldset>
#    <legend>
#     Si conoce la provincia selecciónela:
#    </legend>
#    <ul class="grande">
#     <li class="grande">
#      01
#      <a href="01">
#       Araba/Álava
#      </a>
#     </li>
#     <li class="grande">
#      02
#      <a href="02">
#       Albacete
#      </a>
#     </li>
#     <li class="grande">
#      03
#      <a href="03">
#       Alicante
#      </a>
#     </li>
#     <li class="grande">
#      04
#      <a href="04">
#       Almería
#      </a>
#     </li>
#     <li class="grande">
#      05
#      <a href="05">
#       Ávila
#      </a>
#     </li>
#     <li class="grande">
#      06
#      <a href="06">
#       Badajoz
#      </a>
#     </li>
#     <li class="grande">
#      07
#      <a href="07">
#       Illes Balears
#      </a>
#     </li>
#     <li class="grande">
#      08
#      <a href="08">
#       Barcelona
#      </a>
#     </li>
#     <li class="grande">
#      09
#      <a href="09">
#       Burgos
#      </a>
#     </li>
#     <li class="grande">
#      10
#      <a href="10">
#       Cáceres
#      </a>
#     </li>
#     <li class="grande">
#      11
#      <a href="11">
#       Cádiz
#      </a>
#     </li>
#     <li class="grande">
#      12
#      <a href="12">
#       Castellón
#      </a>
#     </li>
#     <li class="grande">
#      13
#      <a href="13">
#       Ciudad Real
#      </a>
#     </li>
#     <li class="grande">
#      14
#      <a href="14">
#       Córdoba
#      </a>
#     </li>
#     <li class="grande">
#      15
#      <a href="15">
#       Coruña
#      </a>
#     </li>
#     <li class="grande">
#      16
#      <a href="16">
#       Cuenca
#      </a>
#     </li>
#     <li class="grande">
#      17
#      <a href="17">
#       Girona
#      </a>
#     </li>
#     <li class="grande">
#      18
#      <a href="18">
#       Granada
#      </a>
#     </li>
#     <li class="grande">
#      19
#      <a href="19">
#       Guadalajara
#      </a>
#     </li>
#     <li class="grande">
#      20
#      <a href="20">
#       Gipuzkoa
#      </a>
#     </li>
#     <li class="grande">
#      21
#      <a href="21">
#       Huelva
#      </a>
#     </li>
#     <li class="grande">
#      22
#      <a href="22">
#       Huesca
#      </a>
#     </li>
#     <li class="grande">
#      23
#      <a href="23">
#       Jaén
#      </a>
#     </li>
#     <li class="grande">
#      24
#      <a href="24">
#       León
#      </a>
#     </li>
#     <li class="grande">
#      25
#      <a href="25">
#       Lleida
#      </a>
#     </li>
#     <li class="grande">
#      26
#      <a href="26">
#       La Rioja
#      </a>
#     </li>
#     <li class="grande">
#      27
#      <a href="27">
#       Lugo
#      </a>
#     </li>
#     <li class="grande">
#      28
#      <a href="28">
#       Madrid
#      </a>
#     </li>
#     <li class="grande">
#      29
#      <a href="29">
#       Málaga
#      </a>
#     </li>
#     <li class="grande">
#      30
#      <a href="30">
#       Murcia
#      </a>
#     </li>
#     <li class="grande">
#      31
#      <a href="31">
#       Navarra
#      </a>
#     </li>
#     <li class="grande">
#      32
#      <a href="32">
#       Ourense
#      </a>
#     </li>
#     <li class="grande">
#      33
#      <a href="33">
#       Asturias
#      </a>
#     </li>
#     <li class="grande">
#      34
#      <a href="34">
#       Palencia
#      </a>
#     </li>
#     <li class="grande">
#      35
#      <a href="35">
#       Las Palmas
#      </a>
#     </li>
#     <li class="grande">
#      36
#      <a href="36">
#       Pontevedra
#      </a>
#     </li>
#     <li class="grande">
#      37
#      <a href="37">
#       Salamanca
#      </a>
#     </li>
#     <li class="grande">
#      38
#      <a href="38">
#       S.C. Tenerife
#      </a>
#     </li>
#     <li class="grande">
#      39
#      <a href="39">
#       Cantabria
#      </a>
#     </li>
#     <li class="grande">
#      40
#      <a href="40">
#       Segovia
#      </a>
#     </li>
#     <li class="grande">
#      41
#      <a href="41">
#       Sevilla
#      </a>
#     </li>
#     <li class="grande">
#      42
#      <a href="42">
#       Soria
#      </a>
#     </li>
#     <li class="grande">
#      43
#      <a href="43">
#       Tarragona
#      </a>
#     </li>
#     <li class="grande">
#      44
#      <a href="44">
#       Teruel
#      </a>
#     </li>
#     <li class="grande">
#      45
#      <a href="45">
#       Toledo
#      </a>
#     </li>
#     <li class="grande">
#      46
#      <a href="46">
#       Valencia
#      </a>
#     </li>
#     <li class="grande">
#      47
#      <a href="47">
#       Valladolid
#      </a>
#     </li>
#     <li class="grande">
#      48
#      <a href="48">
#       Bizkaia
#      </a>
#     </li>
#     <li class="grande">
#      49
#      <a href="49">
#       Zamora
#      </a>
#     </li>
#     <li class="grande">
#      50
#      <a href="50">
#       Zaragoza
#      </a>
#     </li>
#     <li class="grande">
#      51
#      <a href="51">
#       Ceuta
#      </a>
#     </li>
#     <li class="grande">
#      52
#      <a href="52">
#       Melilla
#      </a>
#     </li>
#    </ul>
#   </fieldset>
#   <br/>
#   <br/>
#   <fieldset>
#    <legend>
#     Búsqueda rápida:
#    </legend>
#    <gcse:searchbox-only resultsurl="https://www.codigospostales.com/busca.html">
#    </gcse:searchbox-only>
#   </fieldset>
#   <div style="clear:both">
#   </div>
#   <br/>
#   <form action="mapa.cgi" method="get">
#    <fieldset>
#     <legend>
#      Si necesita todos los códigos:
#     </legend>
#     <a href="descarga.html">
#      Descarga de la base de datos de codigos postales
#     </a>
#    </fieldset>
#   </form>
#   <form action="mapa.cgi" method="get">
#    <fieldset style="float:right;">
#     <legend>
#      Si quiere ver un mapa:
#     </legend>
#     <a href="mapfus.html">
#      Mapa interactivo de códigos postales
#     </a>
#    </fieldset>
#   </form>
#   <div style="clear:both">
#   </div>
#   <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <ins class="adsbygoogle" data-ad-client="ca-pub-2125689151323495" data-ad-format="auto" data-ad-slot="7246653698" style="display:block">
#   </ins>
#   <script type="text/javascript">
#    (adsbygoogle = window.adsbygoogle || []).push({});
#   </script>
#   <div style="clear:both">
#   </div>
#   <fieldset style="float:left;">
#    <legend>
#     Si sabe el código postal:
#    </legend>
#    <input class="codigo" id="codigo" name="codigo" pattern="[0-9]{5}" required="" size="5" type="text"/>
#    (5 dígitos)
#    <input class="submit" id="cod5" onclick='window.location="/" + document.getElementById("codigo").value ' type="submit" value="Búsqueda inversa"/>
#   </fieldset>
#   <p class="pie">
#    <i>
#     Política de Cookies
#     <br/>
#     Las cookies de este sitio web se usan para personalizar el contenido y los anuncios, ofrecer funciones de redes sociales y analizar el tráfico.
# 	Además, compartimos información sobre el uso que haga del sitio web con nuestros partners de redes sociales, publicidad y análisis web,
# 	quienes pueden combinarla con otra información que les haya proporcionado o que hayan recopilado a partir del uso que haya hecho de sus servicios.
#   Si continua navegando, consideramos que acepta su uso.
#   Puede obtener mas información, o bien conocer cómo cambiar la configuración, en nuestra
#     <a href="cookies.html">
#      política de cookies
#     </a>
#     .
#   Pinche el enlace para mayor información.
#     <br/>
#     Para cualquier duda, diríjase a:
#     <a href="mailto:codigospostales@gmail.com">
#      codigospostales@gmail.com
#     </a>
#    </i>
#   </p>
#  </body>
# </html>

# %%
soup.fieldset.li
print(soup.fieldset.li.a.string)
print(soup.fieldset.li.get_text())
# Out:
# Araba/Ãlava
# 01 Araba/Ãlava

# %%
for soup.fieldset.li in soup.find_all('li'):
    provincia = soup.fieldset.li.text
    print(provincia)
# Out:
# 01 Araba/Ãlava
# 02 Albacete
# 03 Alicante
# 04 AlmerÃ­a
# 05 Ãvila
# 06 Badajoz
# 07 Illes Balears
# 08 Barcelona
# 09 Burgos
# 10 CÃ¡ceres
# 11 CÃ¡diz
# 12 CastellÃ³n
# 13 Ciudad Real
# 14 CÃ³rdoba
# 15 CoruÃ±a
# 16 Cuenca
# 17 Girona
# 18 Granada
# 19 Guadalajara
# 20 Gipuzkoa
# 21 Huelva
# 22 Huesca
# 23 JaÃ©n
# 24 LeÃ³n
# 25 Lleida
# 26 La Rioja
# 27 Lugo
# 28 Madrid
# 29 MÃ¡laga
# 30 Murcia
# 31 Navarra
# 32 Ourense
# 33 Asturias
# 34 Palencia
# 35 Las Palmas
# 36 Pontevedra
# 37 Salamanca
# 38 S.C. Tenerife
# 39 Cantabria
# 40 Segovia
# 41 Sevilla
# 42 Soria
# 43 Tarragona
# 44 Teruel
# 45 Toledo
# 46 Valencia
# 47 Valladolid
# 48 Bizkaia
# 49 Zamora
# 50 Zaragoza
# 51 Ceuta
# 52 Melilla

# %%
c = 'piña'
u = c.decode('utf8')
u
c2 = u.encode
# Out:
# u'pi\xf1a'
